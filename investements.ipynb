# %% [markdown]
# <a href="https://colab.research.google.com/github/soumyazyx/colab_notebooks/blob/main/investements.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Recreate the data with a more readable structure
data = [
    {'Date': '2017-03-01', 'Company': 'Oracle', 'Total': 421898},
    {'Date': '2018-03-01', 'Company': 'Oracle', 'Total': 1126870},
    {'Date': '2019-07-01', 'Company': 'Mphasis', 'Total': 1473732},
    {'Date': '2022-01-01', 'Company': 'JPMC', 'Total': 2514995},
    {'Date': '2022-04-14', 'Company': 'WF', 'Total': 2527059},
    {'Date': '2022-05-01', 'Company': 'WF', 'Total': 2580817},
    {'Date': '2022-06-01', 'Company': 'WF', 'Total': 2491754},
    {'Date': '2022-07-07', 'Company': 'WF', 'Total': 2441125},
    {'Date': '2022-08-04', 'Company': 'WF', 'Total': 2537117},
    {'Date': '2022-09-04', 'Company': 'WF', 'Total': 2512699},
    {'Date': '2022-10-01', 'Company': 'WF', 'Total': 2441585},
    {'Date': '2022-11-02', 'Company': 'WF', 'Total': 2583754},
    {'Date': '2022-12-04', 'Company': 'WF', 'Total': 2604214},
    {'Date': '2023-01-04', 'Company': 'WF', 'Total': 2665451},
    {'Date': '2023-02-04', 'Company': 'WF', 'Total': 2784764},
    {'Date': '2023-03-04', 'Company': 'WF', 'Total': 2932235},
    {'Date': '2023-05-04', 'Company': 'WF', 'Total': 2876742},
    {'Date': '2023-06-04', 'Company': 'WF', 'Total': 2836774},
    {'Date': '2023-07-04', 'Company': 'WF', 'Total': 3033003},
    {'Date': '2023-08-04', 'Company': 'WF', 'Total': 3138976},
    {'Date': '2023-09-04', 'Company': 'WF', 'Total': 3252790},
    {'Date': '2023-10-04', 'Company': 'WF', 'Total': 3201308},
    {'Date': '2023-12-01', 'Company': 'WF', 'Total': 3530383},
    {'Date': '2024-01-01', 'Company': 'WF', 'Total': 3708000},
    {'Date': '2024-02-01', 'Company': 'WF', 'Total': 3849000},
    {'Date': '2024-03-01', 'Company': 'WF', 'Total': 4064500},
    {'Date': '2024-04-01', 'Company': 'WF', 'Total': 4557300},
    {'Date': '2024-05-01', 'Company': 'WF', 'Total': 4468277},
    {'Date': '2024-06-01', 'Company': 'WF', 'Total': 4389717},
    {'Date': '2024-07-06', 'Company': 'NO JOB', 'Total': 4780592},
    {'Date': '2024-08-06', 'Company': 'Qualcomm', 'Total': 5299559},
    {'Date': '2024-09-06', 'Company': 'Qualcomm', 'Total': 5540652},
    {'Date': '2024-10-06', 'Company': 'Qualcomm', 'Total': 5366579},
    {'Date': '2024-12-01', 'Company': 'Qualcomm', 'Total': 5120084},
    {'Date': '2025-01-01', 'Company': 'Qualcomm', 'Total': 5227867},
]

# Create a DataFrame
df = pd.DataFrame(data)
# Convert 'Date' to datetime and set as index
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date', inplace=True)

# Convert 'Total' to lakhs
df['Total'] = df['Total'] / 100000

# Plotting
plt.figure(figsize=(12, 6))

# Plot each company separately
for company in df['Company'].unique():
    company_data = df[df['Company'] == company]
    plt.plot(company_data.index, company_data['Total'], marker='o', label=company)

# Annotate the very last data point
last_point = df.iloc[-1]
plt.annotate(f'{last_point["Total"]:.2f}',
             xy=(last_point.name, last_point["Total"]),
             xytext=(5, 5),
             textcoords='offset points')

plt.title('Total Values Over Time by Company')
plt.xlabel('Date')
plt.ylabel('Total (in Lakhs)')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()

# Show the plot
plt.show()
